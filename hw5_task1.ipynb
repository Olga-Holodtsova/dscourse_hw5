# %%
Часть 1: Основы работы с данными
Создайте текстовый файл с данными и прочитайте его в Python.
Изучите разные типы данных в Python (int, float, str, list, dictionary) и создайте переменные разных типов.
Выполните агрегацию данных (например, вычислите среднее значение чисел в списке).
Преобразуйте данные из одного типа в другой (например, преобразуйте строку в число и наоборот).
Создайте график на основе данных с использованием библиотеки Matplotlib.

# %%
#Создайте текстовый файл с данными и прочитайте его в Python.
with open('mind.txt', 'w') as f:
    f.write('Загру́зка созна́ния!')

# %%
#Изучите разные типы данных в Python (int, float, str, list, dictionary) и создайте переменные разных типов.
# Создание переменной типа int
x = 5

# Создание переменной типа float
y = 3.14

# Создание переменной типа str
z = "Hello, world!"

# Создание переменной типа list
my_list = [1, 2, 3, 4, 5]

# Создание переменной типа dict
my_dict = {"name": "John", "age": 30}

# %%
from typing import List

name: str = 'Оля'
age: int = 37
height_in_meters: float = 1,68
children: List[str] = ['Кирилл']
print(f"List: {name}, {age}, {height_in_meters}, {children}")

my_dict = {"name": "Академия_BELHARD", "group": 2}
for value in my_dict.values():
    print(value)
# Out:
# List: Оля, 37, (1, 68), ['Кирилл']
# Академия_BELHARD
# 2

# %%
#Выполните агрегацию данных (например, вычислите среднее значение чисел в списке).
numbers = [1, 2, 3, 4, 5]
average = sum(numbers) / len(numbers)
print(f"Average: {average}")
# Out:
# Average: 3.0

# %%
#Выполните агрегацию данных (агрегация строк)
def join_numbers_from_range(start, end):
    return ''.join([str(i) for i in range(start, end+1)])
join_numbers_from_range(1, 10)
# Out:
# '12345678910'

# %%
#Преобразуйте данные из одного типа в другой (например, преобразуйте строку в число и наоборот).
string_number = '123'
integer_number = int(string_number)
print(integer_number)

integer_number = 123
string_number = str(integer_number)
print(string_number)
# Out:
# 123
# 123

# %%
#Создайте график на основе данных с использованием библиотеки Matplotlib.

import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('График линейной функции')
plt.show()
